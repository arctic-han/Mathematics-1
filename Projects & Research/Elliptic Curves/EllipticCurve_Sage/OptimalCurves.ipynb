# %%
# Here is an algorithm for finding optimal elliptic curves, suitable for cryptogtraphy. It's only input is just any
# prime power q=p^r. 
# We range p over primes and r over any integer. We wish to compute for p some 100 digit prime, and also for 
# p=2,3,5,7,9 and thier close powers. Since the algotrithm grows fast in complexity (check by how much once algorithm 
# is finished, we have at least O(p^5)), it is advised not to input very large q, other than the 100 digit prime.

# %%
from __future__ import print_function # Just import some of the print function's properties
                                        # to make output bearable.

# %%
p = 3; r = 2
q = p^r

for a1 in range(q):
    for a2 in range(q):
        for a3 in range(q):
            for a4 in range(q):
                for a6 in range(q):
                    b2=a1^2+4*a2; b4=a1*a3+2*a4; b6=a3^2+4*a6; b8=a1^2*a6-a1*a3*a4+a2*a3^2+4*a2*a6-a4^2
                    
                    delta=-b2^2*b8-8*b4^3-27*b6^2+9*b2*b4*b6
                    if delta % p == 0:
                        print("\n")
                    elif order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])) == q+1+2*sqrt(q):
                            print(EllipticCurve(GF(q),[a1,a2,a3,a4,a6]),"is an optimal curve of order: ",
                                  order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])), "\n")
# Out:
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# ...
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 2 over Finite Field in z2 of size 3^2 is an optimal curve of order:  16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7dcb9a61d73a> in <module>()
#      14                     elif order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])) == q+Integer(1)+Integer(2)*sqrt(q):
#      15                             print(EllipticCurve(GF(q),[a1,a2,a3,a4,a6]),"is an optimal curve of order: ",
# ---> 16                                   order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])), "\n")
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/structure/factory.pyx in sage.structure.factory.UniqueFactory.__call__ (build/cythonized/sage/structure/factory.c:2060)()
#     365             False
#     366         """
# --> 367         key, kwds = self.create_key_and_extra_args(*args, **kwds)
#     368         version = self.get_version(sage_version)
#     369         return self.get_object(version, key, kwds)
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/rings/finite_rings/finite_field_constructor.pyc in create_key_and_extra_args(self, order, name, modulus, names, impl, proof, check_irreducible, prefix, repr, elem_cache, **kwds)
#     579                 else:
#     580                     if sage.rings.polynomial.polynomial_element.is_Polynomial(modulus):
# --> 581                         modulus = modulus.change_variable_name('x')
#     582                     modulus = R(modulus).monic()
#     583
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/rings/polynomial/polynomial_element.pyx in sage.rings.polynomial.polynomial_element.Polynomial.change_variable_name (build/cythonized/sage/rings/polynomial/polynomial_element.c:30982)()
#    3197         """
#    3198         R = self._parent.base_ring()[var]
# -> 3199         return R(self.list(copy=False))
#    3200
#    3201     def change_ring(self, R):
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9197)()
#     898         if mor is not None:
#     899             if no_extra_args:
# --> 900                 return mor._call_(x)
#     901             else:
#     902                 return mor._call_with_args(x, args, kwds)
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4441)()
#     155         cdef Parent C = self._codomain
#     156         try:
# --> 157             return C._element_constructor(x)
#     158         except Exception:
#     159             if print_warnings:
#
# /Applications/SageMath-8.8.app/Contents/Resources/sage/local/lib/python2.7/site-packages/sage/rings/polynomial/polynomial_ring.pyc in _element_constructor_(self, x, check, is_gen, construct, **kwds)
#     318         return unpickle_PolynomialRing, args
#     319
# --> 320     def _element_constructor_(self, x=None, check=True, is_gen=False,
#     321                               construct=False, **kwds):
#     322         r"""
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
p = 5; r =1
q = p^r

for a6 in range(q):
    for a4 in range(q):
        for a3 in range(q):
            for a2 in range(q):
                for a1 in range(q):
                    b2=a1^2+4*a2; b4=a1*a3+2*a4; b6=a3^2+4*a6; b8=a1^2*a6-a1*a3*a4+a2*a3^2+4*a2*a6-a4^2
                    
                    delta=-b2^2*b8-8*b4^3-27*b6^2+9*b2*b4*b6
                    if delta % p == 0:
                        print("")
                    else:
                        E = EllipticCurve(GF(q),[a1,a2,a3,a4,a6])
                        print(E)
# Out:
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 2*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x^2 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 2*x^2 + x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x^2 + x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x^2 + x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + y = x^3 + 2*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 2*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 + x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 + x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 + 2*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 + 3*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 4*x over Finite Field of size 5
#
#
#
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + 4*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 + 4*x over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 + 4*x over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + 1 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x^2 + 1 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 1 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + 1 over Finite Field of size 5
# ...
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
#
#
#
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 2*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
#
#
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 3*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 2*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 + 3*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*y = x^3 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x + 4 over Finite Field of size 5
#
#
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 2*x*y + 2*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 2*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 2*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + 3*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
#
#
# Elliptic Curve defined by y^2 + x*y + 3*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 3*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 3*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 2*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 4*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + x*y + 4*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 3*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
#
# Elliptic Curve defined by y^2 + 2*x*y + 4*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 3*x*y + 4*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
# Elliptic Curve defined by y^2 + 4*x*y + 4*y = x^3 + 4*x^2 + 4*x + 4 over Finite Field of size 5
