# %%
# Here is an algorithm for finding optimal elliptic curves, suitable for cryptogtraphy. It's only input is just any
# prime power q=p^r. 
# We range p over primes and r over any integer. We wish to compute for p some 100 digit prime, and also for 
# p=2,3,5,7,9 and thier close powers. Since the algotrithm grows fast in complexity (check by how much once algorithm 
# is finished, we have at least O(p^5)), it is advised not to input very large q, other than the 100 digit prime.

# %%
from __future__ import print_function # Just import some of the print function's properties
                                        # to make output bearable.

# %%
p = 2; r = 2
q = p^r

for a1 in range(q):
    for a2 in range(q):
        for a3 in range(q):
            for a4 in range(q):
                for a6 in range(q):
                    b2=a1^2+4*a2; b4=a1*a3+2*a4; b6=a3^2+4*a6; b8=a1^2*a6-a1*a3*a4+a2*a3^2+4*a2*a6-a4^2
                    
                    delta=-b2^2*b8-8*b4^3-27*b6^2+9*b2*b4*b6
                    if delta % p == 0:
                        print("\n")
                    elif order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])) == q+1+2*sqrt(q):
                            print(EllipticCurve(GF(q),[a1,a2,a3,a4,a6]),"is an optimal curve of order: ",
                                  order(EllipticCurve(GF(q),[a1,a2,a3,a4,a6])), "\n")
# Out:
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2 is an optimal curve of order:  9
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2 is an optimal curve of order:  9

# %%
p = 2; r =2
q = p^r

for a6 in range(q):
    for a4 in range(q):
        for a3 in range(q):
            for a2 in range(q):
                for a1 in range(q):
                    b2=a1^2+4*a2; b4=a1*a3+2*a4; b6=a3^2+4*a6; b8=a1^2*a6-a1*a3*a4+a2*a3^2+4*a2*a6-a4^2
                    
                    delta=-b2^2*b8-8*b4^3-27*b6^2+9*b2*b4*b6
                    if delta % p == 0:
                        print("")
                    else:
                        E = EllipticCurve(GF(q),[a1,a2,a3,a4,a6])
                        print(E)
# Out:
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 + x over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + x*y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + x*y + y = x^3 + x + 1 over Finite Field in z2 of size 2^2
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
#
# Elliptic Curve defined by y^2 + y = x^3 + x^2 + x + 1 over Finite Field in z2 of size 2^2
